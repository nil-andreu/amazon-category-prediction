# %%
import pandas as pd
from tqdm import tqdm
from datetime import datetime

# %% [markdown]
# ## Loading Data

# %%
df = pd.read_csv(
    '../shared/data/amz_products_small_pre_processed.csv.gz', 
    compression='gzip'
)

# %%
df
# Out:
#         also_buy                                          also_view  \
# 0            NaN                                                NaN
# 1            NaN                                                NaN
# 2            NaN                                                NaN
# 3            NaN  ('B007KLMLRM', 'B007KLMNNE', 'B0085FOJ90', 'B0...
# 4            NaN                                                NaN
# ...          ...                                                ...
# 1229093      NaN                                                NaN
# 1229094      NaN                                    ('B07FPGPVH5',)
# 1229095      NaN                                                NaN
# 1229096      NaN                                                NaN
# 1229097      NaN                                                NaN
#
#                asin            brand  \
# 0        B00ADZ3WUM              NSI
# 1        B005VII5IU   General Motors
# 2        B001QTEKVO              JLM
# 3        B00HWI43Q0    Spec-D Tuning
# 4        B0050VHRFK  Oracle Lighting
# ...             ...              ...
# 1229093  B00CLBJS68        Filemaker
# 1229094  B00CNLGPMQ             Sage
# 1229095  B00EVOU7FO           McAfee
# 1229096  B00MV94V76              YBS
# 1229097  B013F97H0I        Kaspersky
#
#                                                description  \
# 0        ('Bumpersticker: A day without sunshine is lik...
# 1        ('This is the official Genuine General Motors ...
# 2        ('HID Xenon lights are designed to be at least...
# 3        ('Brand new in original packaging. Exactly the...
# 4        ('Oracle Flush LED switches combines styling a...
# ...                                                    ...
# 1229093      ('Filemaker Pro 12 Np Edu Train Series Dvd',)
# 1229094  ('<div class="aplus">  <div class="three-fourt...
# 1229095  ('Mcafee, Inc. Mis14edv1raa Mcafee Internet Se...
# 1229096  ('This Package includes ONLY the License Upgra...
# 1229097  ('1YR KIS 2016 3DT COM LICS+LTDMNT BOX KL1941A...
#
#                                                    feature  \
# 0        ('Official Licensed Die-Cut Sticker Designed b...
# 1        ('This is the official Genuine General Motors ...
# 2        ('Will run for approx 2500 hours', 'Produces 2...
# 3        ('Features 1 pair of Red & Smoked lens Tail Li...
# 4        ('Heavy stainless steel construction', 'LED il...
# ...                                                    ...
# 1229093                                                NaN
# 1229094  ('Organize your finances', 'Pay bills and get ...
# 1229095  ('A quality product by MCAFEE, INC.', 'A quali...
# 1229096  ('Nuance Dragon Naturally Speaking Premium 13....
# 1229097  ('Kaspersky Internet Security 2016 - 3 Devices...
#
#                                                      image   price  \
# 0                                                      NaN    4.68
# 1                                                      NaN  213.16
# 2        ('https://images-na.ssl-images-amazon.com/imag...     NaN
# 3        ('https://images-na.ssl-images-amazon.com/imag...    8.63
# 4        ('https://images-na.ssl-images-amazon.com/imag...   19.95
# ...                                                    ...     ...
# 1229093                                                NaN     NaN
# 1229094                                                NaN  299.95
# 1229095                                                NaN   31.80
# 1229096                                                NaN     NaN
# 1229097                                                NaN     NaN
#
#                                                      title         main_cat
# 0        NSI - A Day Without Sunshine is Like, Well, Ni...       Automotive
# 1        Genuine GM Parts 10341533 Rear Bumper Valance ...       Automotive
# 2         JLM HID Conversion Kit H13 (9008) Dual Tube B...       Automotive
# 3        Spec-D Tuning LT-E362RG-F2-APC New 3D Light Ba...       Automotive
# 4        Oracle Lighting LSGQ16FW White LED On/Off Flus...       Automotive
# ...                                                    ...              ...
# 1229093        FileMaker Pro - ( v. 12 ) - complete packag  All Electronics
# 1229094             Sage 50 Pro Accounting 2014 US Edition  All Electronics
# 1229095                     MFE INTERNET SECURITY 1PC 2014  All Electronics
# 1229096  YBS Nuance Dragon Naturally Speaking Premium 1...  All Electronics
# 1229097                      1YR KIS 2016 3DT COM LICS+LTD  All Electronics
#
# [1229098 rows x 10 columns]

# %%
df.main_cat.nunique()
# Out:
# 22

# %% [markdown]
# ### Brand Statistics

# %% [markdown]
# Knowing which is the brand can be interesting, as we could create a map between the brand and the probability of being of a certain main category.

# %%
import sys
sys.path.append('../')

# %%
from shared.model.data.features.engineering.brand import BrandMapCategoryProbabilities

# %%
brand_engineering = BrandMapCategoryProbabilities(df)

# %%
brand_df = brand_engineering.get_brand_df()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8524/8524 [08:41<00:00, 16.35it/s]

# %%
brand_df.head(3)
# Out:
#          Books  Grocery  Amazon Home  Digital Music  Movies & TV  \
# Other     0.12     0.07         0.07           0.07         0.06
# Generic   0.00     0.00         0.05           0.00         0.00
# uxcell    0.00     0.00         0.03           0.00         0.00
#
#          Sports & Outdoors  Tools & Home Improvement  Amazon Fashion  \
# Other                 0.06                      0.05            0.05
# Generic               0.02                      0.03            0.01
# uxcell                0.01                      0.22            0.00
#
#          Toys & Games  Pet Supplies  ...  Office Products  \
# Other            0.05          0.04  ...             0.04
# Generic          0.03          0.02  ...             0.07
# uxcell           0.00          0.08  ...             0.05
#
#          Cell Phones & Accessories  Industrial & Scientific  Computers  \
# Other                         0.04                     0.04       0.03
# Generic                       0.19                     0.02       0.23
# uxcell                        0.01                     0.35       0.04
#
#          All Electronics  Musical Instruments  Home Audio & Theater  \
# Other               0.02                 0.02                  0.02
# Generic             0.11                 0.02                  0.09
# uxcell              0.09                 0.01                  0.03
#
#          Camera & Photo  Health & Personal Care  Video Games
# Other              0.02                    0.02         0.01
# Generic            0.04                    0.01         0.00
# uxcell             0.01                    0.01         0.00
#
# [3 rows x 22 columns]

# %% [markdown]
# We could check if certain categories have some brands with probability of 100%.

# %%
(brand_df == 1).any()
# Out:
# Books                        True
# Grocery                      True
# Amazon Home                  True
# Digital Music                True
# Movies & TV                  True
# Sports & Outdoors            True
# Tools & Home Improvement     True
# Amazon Fashion               True
# Toys & Games                 True
# Pet Supplies                 True
# Arts, Crafts & Sewing        True
# Automotive                   True
# Office Products              True
# Cell Phones & Accessories    True
# Industrial & Scientific      True
# Computers                    True
# All Electronics              True
# Musical Instruments          True
# Home Audio & Theater         True
# Camera & Photo               True
# Health & Personal Care       True
# Video Games                  True
# dtype: bool

# %%
brand_df[(brand_df > .95).any(1)]
# Out:
#                  Books  Grocery  Amazon Home  Digital Music  Movies & TV  \
# Various Artists    0.0      0.0          0.0           0.98         0.02
# ACDelco            0.0      0.0          0.0           0.00         0.00
# Small Parts        0.0      0.0          0.0           0.00         0.00
# Yu-Gi-Oh!          0.0      0.0          0.0           0.00         0.00
# Dorman             0.0      0.0          0.0           0.00         0.00
# ...                ...      ...          ...            ...          ...
# Buster Crabbe      0.0      0.0          0.0           0.00         1.00
# Gamblin            0.0      0.0          0.0           0.00         0.00
# Reunion Blues      0.0      0.0          0.0           0.00         0.00
# Muttluks           0.0      0.0          0.0           0.00         0.00
# Beyond Yoga        0.0      0.0          0.0           0.00         0.00
#
#                  Sports & Outdoors  Tools & Home Improvement  Amazon Fashion  \
# Various Artists                0.0                      0.00             0.0
# ACDelco                        0.0                      0.01             0.0
# Small Parts                    0.0                      0.00             0.0
# Yu-Gi-Oh!                      0.0                      0.00             0.0
# Dorman                         0.0                      0.00             0.0
# ...                            ...                       ...             ...
# Buster Crabbe                  0.0                      0.00             0.0
# Gamblin                        0.0                      0.00             0.0
# Reunion Blues                  0.0                      0.00             0.0
# Muttluks                       0.0                      0.00             0.0
# Beyond Yoga                    1.0                      0.00             0.0
#
#                  Toys & Games  Pet Supplies  ...  Office Products  \
# Various Artists           0.0           0.0  ...              0.0
# ACDelco                   0.0           0.0  ...              0.0
# Small Parts               0.0           0.0  ...              0.0
# Yu-Gi-Oh!                 1.0           0.0  ...              0.0
# Dorman                    0.0           0.0  ...              0.0
# ...                       ...           ...  ...              ...
# Buster Crabbe             0.0           0.0  ...              0.0
# Gamblin                   0.0           0.0  ...              0.0
# Reunion Blues             0.0           0.0  ...              0.0
# Muttluks                  0.0           1.0  ...              0.0
# Beyond Yoga               0.0           0.0  ...              0.0
#
#                  Cell Phones & Accessories  Industrial & Scientific  \
# Various Artists                        0.0                      0.0
# ACDelco                                0.0                      0.0
# Small Parts                            0.0                      1.0
# Yu-Gi-Oh!                              0.0                      0.0
# Dorman                                 0.0                      0.0
# ...                                    ...                      ...
# Buster Crabbe                          0.0                      0.0
# Gamblin                                0.0                      0.0
# Reunion Blues                          0.0                      0.0
# Muttluks                               0.0                      0.0
# Beyond Yoga                            0.0                      0.0
#
#                  Computers  All Electronics  Musical Instruments  \
# Various Artists        0.0              0.0                  0.0
# ACDelco                0.0              0.0                  0.0
# Small Parts            0.0              0.0                  0.0
# Yu-Gi-Oh!              0.0              0.0                  0.0
# Dorman                 0.0              0.0                  0.0
# ...                    ...              ...                  ...
# Buster Crabbe          0.0              0.0                  0.0
# Gamblin                0.0              0.0                  0.0
# Reunion Blues          0.0              0.0                  1.0
# Muttluks               0.0              0.0                  0.0
# Beyond Yoga            0.0              0.0                  0.0
#
#                  Home Audio & Theater  Camera & Photo  Health & Personal Care  \
# Various Artists                   0.0             0.0                     0.0
# ACDelco                           0.0             0.0                     0.0
# Small Parts                       0.0             0.0                     0.0
# Yu-Gi-Oh!                         0.0             0.0                     0.0
# Dorman                            0.0             0.0                     0.0
# ...                               ...             ...                     ...
# Buster Crabbe                     0.0             0.0                     0.0
# Gamblin                           0.0             0.0                     0.0
# Reunion Blues                     0.0             0.0                     0.0
# Muttluks                          0.0             0.0                     0.0
# Beyond Yoga                       0.0             0.0                     0.0
#
#                  Video Games
# Various Artists          0.0
# ACDelco                  0.0
# Small Parts              0.0
# Yu-Gi-Oh!                0.0
# Dorman                   0.0
# ...                      ...
# Buster Crabbe            0.0
# Gamblin                  0.0
# Reunion Blues            0.0
# Muttluks                 0.0
# Beyond Yoga              0.0
#
# [3547 rows x 22 columns]

# %% [markdown]
# So we can see that an important bulk of the brands **always** correspond to a certain category.
#
# We have used a threshold of 20 of minimum observations. Decreasing it could make it more easy to identify those brands, but we would be less confident about their probability.
#
# We could consider the business impact of this, which could maintain overall model metrics (accuracy, f1score, ...) while improving the speed. With a confidence of **95%**:

# %%
df[df.brand.isin(brand_df[(brand_df > .95).any(1)].index)].shape[0] / len(df)
# Out:
# 0.18851466685325335

# %% [markdown]
# So a total of 18% of the classifications of the model could be affected by this.

# %%
brand_engineering.save_brand_df()

# %% [markdown]
# #### Brand Feature

# %% [markdown]
# So basically what we would do is obtaining based on a brand, which are the probabilities.

# %%
from shared.model.data.features.engineering.brand import Brand

# %%
brand_feature_probs = Brand(
    brand_df=brand_df,
).get_feature(brand_name='Other')

# %%
brand_feature_probs
# Out:
# array([0.12, 0.07, 0.07, 0.07, 0.06, 0.06, 0.05, 0.05, 0.05, 0.04, 0.04,
#        0.04, 0.04, 0.04, 0.04, 0.03, 0.02, 0.02, 0.02, 0.02, 0.02, 0.01])
